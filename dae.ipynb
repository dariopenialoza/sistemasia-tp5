# %%
import json
from src.utils import DataConfig, alter_data
from src.autoencoder import Autoencoder
from src.plots import *
from data.font import _font_2, symbols2    

with open('./config_denoising.json', 'r') as f:
    data_config = json.load(f)

c = DataConfig(data_config, _font_2)

MUTATE_PROB = 0.1
CANT_TO_MUTATE = 15
arr_of_errors = []
arr_of_epochs = []
MUTATION=[0.2,0.4,0.6,0.8,1]
for i, prob in enumerate(MUTATION):
    mutated_data = alter_data(c.input_data, prob, CANT_TO_MUTATE)
    mutated_data = np.array(list(mutated_data))
    print(c.input_data.shape)
    print(mutated_data.shape)

    autoencoder = Autoencoder(mutated_data, c.input_data, c.latent_space_size,
                            0.001, c.bias, 5000, 1,
                            c.min_error, 2, [20,10], 
                            c.output_activation, c.hidden_activation, c.beta,
                            c.optimizer_method, c.alpha, c.beta1, c.beta2,
                            c.epsilon)
    mse_errors, total_epochs = autoencoder.train()
    arr_of_errors.append(mse_errors)
    arr_of_epochs.append(total_epochs)

    plot_letters(mutated_data, f"Conjunto de entrenamiento con {CANT_TO_MUTATE} caracteres mutados")

    predicted = []
    for x in mutated_data:
        p = autoencoder.predict(x)
        predicted.append(p)
    plot_letters(predicted, "Eliminacion del ruido")


    arr = []
    for j in range(len(mutated_data)):
        value = autoencoder.latent_space(mutated_data[j])
        arr.append(value)
        print("Latent space value: ", value, " for letter in index ", j)

    plot_latent_space(np.array(arr), symbols2)

colors = ['blue', 'green', 'red', 'orange']

fig, ax = plt.subplots()  
for i, arquitectura in enumerate(MUTATION):
    ax.plot(range(arr_of_epochs[i]), arr_of_errors[i],  label=f"Prob {MUTATION[i]}")
ax.set_title('Evaluacion del error de DAE con distintas probabilidades') 
ax.set_xlabel('Epocas') 
ax.set_ylabel('Error (MSE)')  
ax.legend(loc='best')  
plt.show()
# Out:
# (32, 35)
# (32, 35)
# 0
# 1000
# 2000
# 3000
# 4000
# Finished Training.
#  MSE: 0.4390178250596929
# Latent space value:  [0.98220174 0.25622482]  for letter in index  0
# Latent space value:  [0.01008908 0.730972  ]  for letter in index  1
# Latent space value:  [0.99018336 0.79773833]  for letter in index  2
# Latent space value:  [0.96862816 0.06903753]  for letter in index  3
# Latent space value:  [0.34274089 0.08571043]  for letter in index  4
# Latent space value:  [0.44670848 0.19740952]  for letter in index  5
# Latent space value:  [0.56005919 0.95610717]  for letter in index  6
# Latent space value:  [0.98288641 0.13722996]  for letter in index  7
# Latent space value:  [0.36408013 0.99386064]  for letter in index  8
# Latent space value:  [0.04157386 0.00691407]  for letter in index  9
# Latent space value:  [0.62967928 0.05055   ]  for letter in index  10
# Latent space value:  [0.26090443 0.40727018]  for letter in index  11
# Latent space value:  [0.24580182 0.24665256]  for letter in index  12
# Latent space value:  [0.08353328 0.9432243 ]  for letter in index  13
# Latent space value:  [0.24191825 0.95599317]  for letter in index  14
# Latent space value:  [0.64643892 0.26106755]  for letter in index  15
# Latent space value:  [0.97674432 0.97338658]  for letter in index  16
# Latent space value:  [0.77593397 0.20325879]  for letter in index  17
# Latent space value:  [0.7492279  0.97286158]  for letter in index  18
# Latent space value:  [0.9936917  0.58163309]  for letter in index  19
# Latent space value:  [0.01718721 0.06445094]  for letter in index  20
# Latent space value:  [0.54780863 0.40824929]  for letter in index  21
# Latent space value:  [0.40136219 0.56816788]  for letter in index  22
# Latent space value:  [0.27351765 0.68697   ]  for letter in index  23
# Latent space value:  [0.04726703 0.47033576]  for letter in index  24
# Latent space value:  [0.0051637 0.1490693]  for letter in index  25
# Latent space value:  [0.45667328 0.12534183]  for letter in index  26
# Latent space value:  [0.4006017 0.0126604]  for letter in index  27
# Latent space value:  [0.04139806 0.25060778]  for letter in index  28
# Latent space value:  [0.71715845 0.01236291]  for letter in index  29
# Latent space value:  [0.11951309 0.11331363]  for letter in index  30
# Latent space value:  [0.20207948 0.1969992 ]  for letter in index  31
# (32, 35)
# (32, 35)
# 0
# 1000
# 2000
# 3000
# 4000
# Finished Training.
#  MSE: 0.5330221362009927
# Latent space value:  [0.98823241 0.38646898]  for letter in index  0
# Latent space value:  [0.31630738 0.9878213 ]  for letter in index  1
# Latent space value:  [0.95556876 0.03868455]  for letter in index  2
# Latent space value:  [0.72120815 0.56886359]  for letter in index  3
# Latent space value:  [0.4018315 0.0136775]  for letter in index  4
# Latent space value:  [0.55494696 0.37180668]  for letter in index  5
# Latent space value:  [0.64776877 0.33065885]  for letter in index  6
# Latent space value:  [0.85190439 0.57911294]  for letter in index  7
# Latent space value:  [0.66000115 0.90770449]  for letter in index  8
# Latent space value:  [0.01701406 0.08377829]  for letter in index  9
# Latent space value:  [0.55974243 0.10501468]  for letter in index  10
# Latent space value:  [0.35074771 0.67200139]  for letter in index  11
# Latent space value:  [0.46886522 0.45784437]  for letter in index  12
# Latent space value:  [0.52044837 0.98796405]  for letter in index  13
# Latent space value:  [0.71882184 0.99133022]  for letter in index  14
# Latent space value:  [0.99360617 0.73150641]  for letter in index  15
# Latent space value:  [0.86156196 0.10207226]  for letter in index  16
# Latent space value:  [0.98895734 0.51785323]  for letter in index  17
# Latent space value:  [0.93018248 0.19994697]  for letter in index  18
# Latent space value:  [0.8506009  0.01472948]  for letter in index  19
# Latent space value:  [0.00617961 0.21889371]  for letter in index  20
# Latent space value:  [0.99301754 0.82436682]  for letter in index  21
# Latent space value:  [0.98136634 0.90725439]  for letter in index  22
# Latent space value:  [0.90463189 0.97647222]  for letter in index  23
# Latent space value:  [0.07492666 0.74720851]  for letter in index  24
# Latent space value:  [0.1638898  0.56126815]  for letter in index  25
# Latent space value:  [0.50383538 0.28019171]  for letter in index  26
# Latent space value:  [0.28247502 0.03775546]  for letter in index  27
# Latent space value:  [0.01190883 0.61297844]  for letter in index  28
# Latent space value:  [0.11769954 0.01852058]  for letter in index  29
# Latent space value:  [0.01077996 0.43014161]  for letter in index  30
# Latent space value:  [0.28523235 0.37576597]  for letter in index  31
# (32, 35)
# (32, 35)
# 0
# 1000
# 2000
# 3000
# 4000
# Finished Training.
#  MSE: 0.3489040097868828
# Latent space value:  [0.97753467 0.4379156 ]  for letter in index  0
# Latent space value:  [0.07964611 0.94897382]  for letter in index  1
# Latent space value:  [0.98782182 0.84324823]  for letter in index  2
# Latent space value:  [0.94570711 0.16242841]  for letter in index  3
# Latent space value:  [0.28735287 0.01065955]  for letter in index  4
# Latent space value:  [0.72592523 0.19001174]  for letter in index  5
# Latent space value:  [0.78044722 0.92786252]  for letter in index  6
# Latent space value:  [0.94534863 0.28940642]  for letter in index  7
# Latent space value:  [0.65303663 0.98202338]  for letter in index  8
# Latent space value:  [0.07182173 0.03155974]  for letter in index  9
# Latent space value:  [0.61889269 0.00842993]  for letter in index  10
# Latent space value:  [0.02966649 0.70063601]  for letter in index  11
# Latent space value:  [0.46935954 0.29320418]  for letter in index  12
# Latent space value:  [0.20123727 0.8382238 ]  for letter in index  13
# Latent space value:  [0.2350218  0.64907596]  for letter in index  14
# Latent space value:  [0.75936008 0.38726744]  for letter in index  15
# Latent space value:  [0.86827461 0.86050291]  for letter in index  16
# Latent space value:  [0.83627342 0.48719803]  for letter in index  17
# Latent space value:  [0.95316904 0.97223028]  for letter in index  18
# Latent space value:  [0.95483899 0.04666848]  for letter in index  19
# Latent space value:  [0.01317684 0.0553486 ]  for letter in index  20
# Latent space value:  [0.66210455 0.38512871]  for letter in index  21
# Latent space value:  [0.42118438 0.81737965]  for letter in index  22
# Latent space value:  [0.52688899 0.98688345]  for letter in index  23
# Latent space value:  [0.09891412 0.4652889 ]  for letter in index  24
# Latent space value:  [0.01710507 0.18357173]  for letter in index  25
# Latent space value:  [0.61807263 0.12927595]  for letter in index  26
# Latent space value:  [0.14361674 0.01457088]  for letter in index  27
# Latent space value:  [0.03005791 0.32032538]  for letter in index  28
# Latent space value:  [0.51432262 0.00746212]  for letter in index  29
# Latent space value:  [0.22816465 0.17101769]  for letter in index  30
# Latent space value:  [0.41622934 0.24145673]  for letter in index  31
# (32, 35)
# (32, 35)
# 0
# 1000
# 2000
# 3000
# 4000
# Finished Training.
#  MSE: 0.5946658172821048
# Latent space value:  [0.14109315 0.95217659]  for letter in index  0
# Latent space value:  [0.99233519 0.47827985]  for letter in index  1
# Latent space value:  [0.35302383 0.65656044]  for letter in index  2
# Latent space value:  [0.03130081 0.76693788]  for letter in index  3
# Latent space value:  [0.00769525 0.31456807]  for letter in index  4
# Latent space value:  [0.29840247 0.38814785]  for letter in index  5
# Latent space value:  [0.44009438 0.37874226]  for letter in index  6
# Latent space value:  [0.08680012 0.76479732]  for letter in index  7
# Latent space value:  [0.9417022  0.95966981]  for letter in index  8
# Latent space value:  [0.05810342 0.00886319]  for letter in index  9
# Latent space value:  [0.24598182 0.21699515]  for letter in index  10
# Latent space value:  [0.79444202 0.49474529]  for letter in index  11
# Latent space value:  [0.21723819 0.45693273]  for letter in index  12
# Latent space value:  [0.98982997 0.68580187]  for letter in index  13
# Latent space value:  [0.98929741 0.82977499]  for letter in index  14
# Latent space value:  [0.03393929 0.92561436]  for letter in index  15
# Latent space value:  [0.4483933 0.5791378]  for letter in index  16
# Latent space value:  [0.2846523  0.98816071]  for letter in index  17
# Latent space value:  [0.58008711 0.52125917]  for letter in index  18
# Latent space value:  [0.02844694 0.58084298]  for letter in index  19
# Latent space value:  [0.1738801  0.00652025]  for letter in index  20
# Latent space value:  [0.47959379 0.99651031]  for letter in index  21
# Latent space value:  [0.60498684 0.93017617]  for letter in index  22
# Latent space value:  [0.78166008 0.98233767]  for letter in index  23
# Latent space value:  [0.99188671 0.17891936]  for letter in index  24
# Latent space value:  [0.7278922  0.01866524]  for letter in index  25
# Latent space value:  [0.11922136 0.35332205]  for letter in index  26
# Latent space value:  [0.00844616 0.13769668]  for letter in index  27
# Latent space value:  [0.95499203 0.02081966]  for letter in index  28
# Latent space value:  [0.12742963 0.14818122]  for letter in index  29
# Latent space value:  [0.46435397 0.08467586]  for letter in index  30
# Latent space value:  [0.0669619  0.20002318]  for letter in index  31
# (32, 35)
# (32, 35)
# 0
# 1000
# 2000
# 3000
# 4000
# Finished Training.
#  MSE: 0.6606695088854204
# Latent space value:  [0.97931599 0.89513456]  for letter in index  0
# Latent space value:  [0.00613954 0.37938802]  for letter in index  1
# Latent space value:  [0.5758181  0.98216525]  for letter in index  2
# Latent space value:  [0.99483409 0.49483721]  for letter in index  3
# Latent space value:  [0.95667013 0.1300758 ]  for letter in index  4
# Latent space value:  [0.70392314 0.97974174]  for letter in index  5
# Latent space value:  [0.42543294 0.97761425]  for letter in index  6
# Latent space value:  [0.99204071 0.62361319]  for letter in index  7
# Latent space value:  [0.17884085 0.96883559]  for letter in index  8
# Latent space value:  [0.95473943 0.00862314]  for letter in index  9
# Latent space value:  [0.3394235  0.00401417]  for letter in index  10
# Latent space value:  [0.19232306 0.61536651]  for letter in index  11
# Latent space value:  [0.82739679 0.98645549]  for letter in index  12
# Latent space value:  [0.00416171 0.78878403]  for letter in index  13
# Latent space value:  [0.08818024 0.37471904]  for letter in index  14
# Latent space value:  [0.99244862 0.66550273]  for letter in index  15
# Latent space value:  [0.29780379 0.97241174]  for letter in index  16
# Latent space value:  [0.96445684 0.95639162]  for letter in index  17
# Latent space value:  [0.25040893 0.73973474]  for letter in index  18
# Latent space value:  [0.98903779 0.36521837]  for letter in index  19
# Latent space value:  [0.1297882  0.00413819]  for letter in index  20
# Latent space value:  [0.56972849 0.5136081 ]  for letter in index  21
# Latent space value:  [0.05852833 0.96191493]  for letter in index  22
# Latent space value:  [0.10582737 0.66561401]  for letter in index  23
# Latent space value:  [0.02201158 0.16852859]  for letter in index  24
# Latent space value:  [0.02407483 0.01423873]  for letter in index  25
# Latent space value:  [0.99500682 0.24434724]  for letter in index  26
# Latent space value:  [0.97565256 0.06988532]  for letter in index  27
# Latent space value:  [0.02022782 0.10705971]  for letter in index  28
# Latent space value:  [0.43606301 0.00787433]  for letter in index  29
# Latent space value:  [0.22079201 0.11246267]  for letter in index  30
# Latent space value:  [0.5573512  0.05171621]  for letter in index  31
